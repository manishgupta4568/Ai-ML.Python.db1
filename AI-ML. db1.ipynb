# %% [markdown]
# python3

# %%
ction:{a-b}")
print (f"multiplication:{a*b}")
print (f"Division:{a/b}")# Build a calculator
# Concepts: Type Casting, Variable, Data Types

a=int(input("enter the first number"))
b=int(input("enter the second number"))
print ("addition is:", a+b)
print (f"addition is:{a+b}") # F-string(very crucial)
print (f"Subtra
# Out:
# enter the first number5
# enter the second number3
# addition is: 8
# addition is:8
# Subtraction:2
# multiplication:15
# Division:1.6666666666666667

# %% [markdown]
# Project 2:Student info

# %%
name = input("Enter your name:")
age = int(input("Enter your age:"))
dept = input("Enter your department:")

print(f"My name is {name}, age is {age} & the dapartment is {dept}")
# Out:
# Enter your name:ashish
# Enter your age:21
# Enter your department:ECE
# My name is ashish, age is 21 & the dapartment is ECE

# %% [markdown]
# **Excercises**

# %%
#Take city as input and print it
city =input("enter ypur city:")
print(city)
# Out:
# enter ypur city:Begusarai
# Begusarai

# %%
#take two nummbers and print their sum
a=float(input("enter first number:"))
b=float(input("enter second number"))
print(a+b)
# Out:
# enter first number:5
# enter second number7
# 12.0

# %%
# Create variables for name, salary, and job role


name = input ("enter your name:")
salary = float (input("enter your salary:"))
job_role = input ("enter your job role:")

print(f"name is{name},salary is{salary},7 job is {job_role}")
# Out:
# enter your name:Ashish
# enter your salary:50000
# enter your job role:CA
# name isAshish,salary is50000.0,7 job is CA

# %%
#Popular data types in Python

# List vs Tuple

roles = ["AI engineer", "Freelance soft developer", "designer"]

# Set vs Dictionary

names = {"Alex", "Yuli"} #Set
ages = {"Alex":"Data scientist"}

# %% [markdown]
# conditional Statement

# %%
# if-else statement & Identation
# lets check you're eligible for driving or not
age = int(input("enter your age:"))

if age>18:
  print("you can drive")
else:
  print("OOps! Y0u can't drive")
# Out:
# enter your age:25
# you can drive

# %%
# if-else statement & identation
# logical operations: and, or, not

a = int(input("enter a:"))
b = int(input("enter b:"))
c = int(input("enter c:"))

if a>b and a>c:
  print("a is the greatest")
elif b>a and b>c:
  print("b is the gratest")
else:
  print("c is the greatest")
# Out:
# enter a:7
# enter b:5
# enter c:4
# a is the greatest
